# %%
import pandas as pd
import requests
import random

# %%
df=pd.read_csv("./CleanedData/CleanedHousingRcommenderDataset.csv")
df=df[df['property_type']=='All Residential']
attributes=['period_end','county','state','state_code','median_ppsf','tax_burden','medianage','cost_of_living_rank']
df=df[attributes]
df['tax_burden'] = df['tax_burden'].astype(str).apply(lambda x: x.split("%")[0]).astype(float)
df
# Out:
#       period_end            county         state state_code  median_ppsf  \
# 0     2013-03-31   Itawamba County   Mississippi         MS    46.081277
# 1     2015-12-31     Clinch County       Georgia         GA    51.966473
# 2     2015-12-31    Noxubee County   Mississippi         MS    24.549444
# 3     2016-08-31      Amite County   Mississippi         MS    27.938343
# 4     2016-12-31     Chaves County    New Mexico         NM   177.884615
# ...          ...               ...           ...        ...          ...
# 1855  2021-12-31       Cass County      Nebraska         NE   111.116903
# 1856  2021-12-31     DeKalb County     Tennessee         TN   171.168342
# 1857  2021-12-31  Josephine County        Oregon         OR   241.369480
# 1858  2021-12-31   San Saba County         Texas         TX   118.127457
# 1859  2021-12-31     Lehigh County  Pennsylvania         PA   167.086586
#
#       tax_burden  medianage  cost_of_living_rank
# 0           8.99       38.0                 15.0
# 1           7.91       37.0                 35.0
# 2           8.99       38.0                 15.0
# 3           8.99       38.0                 15.0
# 4           8.19       38.0                 30.0
# ...          ...        ...                  ...
# 1855        9.01       37.0                 14.0
# 1856        5.74       39.0                 49.0
# 1857        8.29       39.0                 27.0
# 1858        8.19       35.0                 30.0
# 1859        8.46       41.0                 23.0
#
# [1860 rows x 8 columns]

# %%
forcasted_data=pd.read_csv("CleanedData/ppsf_forcast.csv")
#Housing Recommender System\DataExtraction\CleanedData\ppsf_forecast.csv
forcasted_data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_34804\1434283251.py in <module>
# ----> 1 forcasted_data=pd.read_csv("CleanedData/ppsf_forcast.csv")
#       2 #Housing Recommender System\DataExtraction\CleanedData\ppsf_forecast.csv
#       3 forcasted_data
#
# c:\users\rajee\appdata\local\programs\python\python37\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# c:\users\rajee\appdata\local\programs\python\python37\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# c:\users\rajee\appdata\local\programs\python\python37\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# c:\users\rajee\appdata\local\programs\python\python37\lib\site-packages\pandas\io\parsers\readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# c:\users\rajee\appdata\local\programs\python\python37\lib\site-packages\pandas\io\parsers\readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# c:\users\rajee\appdata\local\programs\python\python37\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# c:\users\rajee\appdata\local\programs\python\python37\lib\site-packages\pandas\io\parsers\base_parser.py in _open_handles(self, src, kwds)
#     227             memory_map=kwds.get("memory_map", False),
#     228             storage_options=kwds.get("storage_options", None),
# --> 229             errors=kwds.get("encoding_errors", "strict"),
#     230         )
#     231
#
# c:\users\rajee\appdata\local\programs\python\python37\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     705                 encoding=ioargs.encoding,
#     706                 errors=errors,
# --> 707                 newline="",
#     708             )
#     709         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'CleanedData/ppsf_forcast.csv'

# %%
def getSchoolRatings(df):
    elem_school=[random.randint(1,10) for i in range(0,len(df))]
    middle_school=[random.randint(1,10) for i in range(0,len(df))]
    high_school=[random.randint(1,10) for i in range(0,len(df))]
    df['elementary_school_rating']=elem_school
    df['middle_school_rating']=middle_school
    df['high_school_rating']=high_school
    return df


df_subset=df[['county','state_code']]
df_unique = df_subset.groupby(by=['county','state_code'], as_index=False).first()
school_ratings=getSchoolRatings(df_unique)
dfinal = df.merge(school_ratings, on=["state_code","county"], how = 'left')
dfinal
# Out:
#       period_end            county         state state_code  median_ppsf  \
# 0     2013-03-31   Itawamba County   Mississippi         MS    46.081277
# 1     2015-12-31     Clinch County       Georgia         GA    51.966473
# 2     2015-12-31    Noxubee County   Mississippi         MS    24.549444
# 3     2016-08-31      Amite County   Mississippi         MS    27.938343
# 4     2016-12-31     Chaves County    New Mexico         NM   177.884615
# ...          ...               ...           ...        ...          ...
# 1855  2021-12-31       Cass County      Nebraska         NE   111.116903
# 1856  2021-12-31     DeKalb County     Tennessee         TN   171.168342
# 1857  2021-12-31  Josephine County        Oregon         OR   241.369480
# 1858  2021-12-31   San Saba County         Texas         TX   118.127457
# 1859  2021-12-31     Lehigh County  Pennsylvania         PA   167.086586
#
#       tax_burden  medianage  cost_of_living_rank  elementary_school_rating  \
# 0           8.99       38.0                 15.0                         8
# 1           7.91       37.0                 35.0                         8
# 2           8.99       38.0                 15.0                         1
# 3           8.99       38.0                 15.0                         5
# 4           8.19       38.0                 30.0                         5
# ...          ...        ...                  ...                       ...
# 1855        9.01       37.0                 14.0                         2
# 1856        5.74       39.0                 49.0                         8
# 1857        8.29       39.0                 27.0                         8
# 1858        8.19       35.0                 30.0                         8
# 1859        8.46       41.0                 23.0                         6
#
#       middle_school_rating  high_school_rating
# 0                        1                   4
# 1                        5                   9
# 2                        3                   9
# 3                        1                   3
# 4                        8                   5
# ...                    ...                 ...
# 1855                    10                   3
# 1856                     3                   6
# 1857                     8                   2
# 1858                    10                  10
# 1859                     8                   8
#
# [1860 rows x 11 columns]

# %%
def getSchoolRatings(df):
    elem_school=[random.randint(1,10) for i in range(0,len(df))]
    middle_school=[random.randint(1,10) for i in range(0,len(df))]
    high_school=[random.randint(1,10) for i in range(0,len(df))]
    df['elementary_school_rating']=elem_school
    df['middle_school_rating']=middle_school
    df['high_school_rating']=high_school
    return df

getSchoolRatings(df)
# Out:
#       period_end            county         state state_code  median_ppsf  \
# 0     2013-03-31   Itawamba County   Mississippi         MS    46.081277
# 1     2015-12-31     Clinch County       Georgia         GA    51.966473
# 2     2015-12-31    Noxubee County   Mississippi         MS    24.549444
# 3     2016-08-31      Amite County   Mississippi         MS    27.938343
# 4     2016-12-31     Chaves County    New Mexico         NM   177.884615
# ...          ...               ...           ...        ...          ...
# 1855  2021-12-31       Cass County      Nebraska         NE   111.116903
# 1856  2021-12-31     DeKalb County     Tennessee         TN   171.168342
# 1857  2021-12-31  Josephine County        Oregon         OR   241.369480
# 1858  2021-12-31   San Saba County         Texas         TX   118.127457
# 1859  2021-12-31     Lehigh County  Pennsylvania         PA   167.086586
#
#       tax_burden  medianage  cost_of_living_rank  elementary_school_rating  \
# 0           8.99       38.0                 15.0                         9
# 1           7.91       37.0                 35.0                         2
# 2           8.99       38.0                 15.0                         7
# 3           8.99       38.0                 15.0                         1
# 4           8.19       38.0                 30.0                         6
# ...          ...        ...                  ...                       ...
# 1855        9.01       37.0                 14.0                         6
# 1856        5.74       39.0                 49.0                         8
# 1857        8.29       39.0                 27.0                         6
# 1858        8.19       35.0                 30.0                         4
# 1859        8.46       41.0                 23.0                         3
#
#       middle_school_rating  high_school_rating
# 0                        7                   8
# 1                       10                   6
# 2                        4                   3
# 3                        6                   7
# 4                        5                   4
# ...                    ...                 ...
# 1855                     9                   2
# 1856                     8                   5
# 1857                     2                   1
# 1858                     6                   4
# 1859                     7                  10
#
# [1860 rows x 11 columns]

# %%
df.to_csv("./CleanedData/HousingRecommenderMetrics.csv")
